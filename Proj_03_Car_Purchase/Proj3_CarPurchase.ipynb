# %%
import pandas as pd

# %%
data = pd.read_csv("Car_Purchasing_Data.csv")

# %%
data.head()
# Out:
#      Customer Name                                    Customer e-mail Country  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu     USA
# 1    Harlan Barnes                                eu.dolor@diam.co.uk     USA
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...     USA
# 3  Jade Cunningham                            malesuada@dignissim.com     USA
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net     USA
#
#    Gender  Age  Annual Salary  Credit Card Debt    Net Worth  \
# 0       0   42    62812.09301      11609.380910  238961.2505
# 1       0   41    66646.89292       9572.957136  530973.9078
# 2       1   43    53798.55112      11160.355060  638467.1773
# 3       1   58    79370.03798      14426.164850  548599.0524
# 4       1   57    59729.15130       5358.712177  560304.0671
#
#    Car Purchase Amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# ...

# %%
data.tail()
# Out:
#     Customer Name                     Customer e-mail Country  Gender  Age  \
# 495        Walter                 ligula@Cumsociis.ca     USA       0   41
# 496         Vanna  Cum.sociis.natoque@Sedmolestie.edu     USA       1   38
# 497         Pearl       penatibus.et@massanonante.com     USA       1   54
# 498          Nell   Quisque.varius@arcuVivamussit.net     USA       1   59
# 499         Marla           Camaron.marla@hotmail.com     USA       1   47
#
#      Annual Salary  Credit Card Debt    Net Worth  Car Purchase Amount
# 495    71942.40291       6995.902524  541670.1016          48901.44342
# 496    56039.49793      12301.456790  360419.0988          31491.41457
# 497    68888.77805      10611.606860  764531.3203          64147.28888
# 498    49811.99062      14013.034510  337826.6382          45442.15353
# 499    61370.67766       9391.341628  462946.4924          45107.22566

# %%
data.shape
# Out:
# (500, 9)

# %%
print("Number of Rows:", data.shape[0])
print("Number of Columns:", data.shape[1])
# Out:
# Number of Rows: 500
# Number of Columns: 9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Customer Name        500 non-null    object
#  1   Customer e-mail      500 non-null    object
#  2   Country              500 non-null    object
#  3   Gender               500 non-null    int64
#  4   Age                  500 non-null    int64
#  5   Annual Salary        500 non-null    float64
#  6   Credit Card Debt     500 non-null    float64
#  7   Net Worth            500 non-null    float64
#  8   Car Purchase Amount  500 non-null    float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 35.3+ KB

# %%
data.describe()
# Out:
#            Gender         Age  Annual Salary  Credit Card Debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.224000   62127.239608       9607.645049
# std      0.500465    7.990339   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   41.000000   54391.977195       7397.515792
# 50%      1.000000   46.000000   62915.497035       9655.035568
# 75%      1.000000   52.000000   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             Net Worth  Car Purchase Amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
data.isnull().sum()
# Out:
# Customer Name          0
# Customer e-mail        0
# Country                0
# Gender                 0
# Age                    0
# Annual Salary          0
# Credit Card Debt       0
# Net Worth              0
# Car Purchase Amount    0
# dtype: int64

# %%
import seaborn as sns
sns.pairplot(data)

# %% [markdown]
#  The last plot shows the relationship between the the car purchase amount and various features

# %%
data.columns
# Out:
# Index(['Customer Name', 'Customer e-mail', 'Country', 'Gender', 'Age',
#        'Annual Salary', 'Credit Card Debt', 'Net Worth',
#        'Car Purchase Amount'],
#       dtype='object')

# %%
X = data.drop(['Customer Name','Customer e-mail','Country','Car Purchase Amount'], axis=1)
y = data['Car Purchase Amount']

# %%
X
# Out:
#      Gender  Age  Annual Salary  Credit Card Debt    Net Worth
# 0         0   42    62812.09301      11609.380910  238961.2505
# 1         0   41    66646.89292       9572.957136  530973.9078
# 2         1   43    53798.55112      11160.355060  638467.1773
# 3         1   58    79370.03798      14426.164850  548599.0524
# 4         1   57    59729.15130       5358.712177  560304.0671
# ..      ...  ...            ...               ...          ...
# 495       0   41    71942.40291       6995.902524  541670.1016
# 496       1   38    56039.49793      12301.456790  360419.0988
# 497       1   54    68888.77805      10611.606860  764531.3203
# 498       1   59    49811.99062      14013.034510  337826.6382
# 499       1   47    61370.67766       9391.341628  462946.4924
#
# [500 rows x 5 columns]

# %%
y
# Out:
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
#           ...
# 495    48901.44342
# 496    31491.41457
# 497    64147.28888
# 498    45442.15353
# 499    45107.22566
# Name: Car Purchase Amount, Length: 500, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler()
X_scaled = sc.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.        , 0.44      , 0.53515116, 0.57836085, 0.22342985],
#        [0.        , 0.42      , 0.58308616, 0.476028  , 0.52140195],
#        [1.        , 0.46      , 0.42248189, 0.55579674, 0.63108896],
#        ...,
#        [1.        , 0.68      , 0.61110973, 0.52822145, 0.75972584],
#        [1.        , 0.78      , 0.37264988, 0.69914746, 0.3243129 ],
#        [1.        , 0.54      , 0.51713347, 0.46690159, 0.45198622]])

# %%
sc1 = MinMaxScaler()
y_reshape = y.values.reshape(-1,1)
y_scaled = sc1.fit_transform(y_reshape)

# %%
y_scaled
# Out:
# array([[0.37072477],
#        [0.50866938],
#        [0.47782689],
#        [0.82285018],
#        [0.66078116],
#        [0.67059152],
#        [0.28064374],
#        [0.54133778],
#        [0.54948752],
#        [0.4111198 ],
#        [0.70486638],
#        [0.46885649],
#        [0.27746526],
#        [0.56702642],
#        [0.57056385],
#        [0.61996151],
#        [0.46217916],
#        [0.49157341],
#        [0.50188722],
#        [0.64545808],
#        [0.59339372],
#        [0.48453965],
#        [0.53860366],
#        [0.53007738],
#        [0.50814651],
#        [0.49841668],
#        [0.3966416 ],
#        [0.56467566],
#        [0.6950749 ],
#        [0.49287831],
#        [0.12090943],
#        [0.50211776],
#        [0.80794216],
#        [0.62661214],
#        [0.43394857],
#        [0.60017103],
#        [0.42223485],
#        [0.01538345],
#        [0.37927499],
#        [0.64539707],
#        [0.51838974],
#        [0.45869677],
#        [0.26804521],
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X_scaled,y_scaled,test_size=0.2,random_state=42)

# %%
X_train
# Out:
# array([[0.        , 0.32      , 0.62918035, 0.48860397, 0.62510252],
#        [1.        , 0.4       , 0.45108063, 0.32606063, 0.21264138],
#        [0.        , 0.78      , 0.44210296, 0.66195711, 0.55716544],
#        ...,
#        [0.        , 0.5       , 0.54451307, 0.18241808, 0.60002003],
#        [1.        , 0.76      , 0.26761617, 0.40760507, 0.40950916],
#        [1.        , 0.2       , 0.60361478, 0.36471292, 0.39230338]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)

svr = SVR()
svr.fit(X_train,y_train)

gbr = GradientBoostingRegressor()
gbr.fit(X_train,y_train)

rfr = RandomForestRegressor()
rfr.fit(X_train,y_train)

xgb = XGBRegressor()
xgb.fit(X_train,y_train)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\User\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_7892\1541250579.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfr.fit(X_train,y_train)
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
# ...

# %%
import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense

# %%
ann = Sequential()

# %% [markdown]
# ## Adding input and first hidden layers

# %%
 ann.add(Dense(25,input_dim=5,activation='relu'))

# %% [markdown]
# # Adding second hidden layer

# %%
ann.add(Dense(25,activation='relu'))

# %% [markdown]
# # Adding output layer

# %%
ann.add(Dense(1,activation='linear'))

# %%
ann.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 25)                150
#
#  dense_1 (Dense)             (None, 25)                650
#
#  dense_2 (Dense)             (None, 1)                 26
#
# ...
# Total params: 826
# Trainable params: 826
# Non-trainable params: 0
# _________________________________________________________________

# %%
ann.compile(optimizer='adam',loss='mean_squared_error')

# %%
ann.fit(X_train,y_train,epochs=100,batch_size=50,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 41ms/step - loss: 0.2872 - val_loss: 0.1494
# Epoch 2/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1446 - val_loss: 0.0689
# Epoch 3/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0798 - val_loss: 0.0498
# Epoch 4/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0598 - val_loss: 0.0471
# Epoch 5/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0493 - val_loss: 0.0389
# Epoch 6/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0380 - val_loss: 0.0272
# Epoch 7/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0287 - val_loss: 0.0195
# Epoch 8/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0233 - val_loss: 0.0157
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0193 - val_loss: 0.0135
# Epoch 10/100
# ...

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = svr.predict(X_test)
y_pred3 = gbr.predict(X_test)
y_pred4 = rfr.predict(X_test)
y_pred5 = xgb.predict(X_test)
y_pred6 = ann.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %% [markdown]
# # Evaluation of models

# %%
from sklearn import metrics

# %%
score1 = metrics.r2_score(y_test,y_pred1)
score2 = metrics.r2_score(y_test,y_pred2)
score3 = metrics.r2_score(y_test,y_pred3)
score4 = metrics.r2_score(y_test,y_pred4)
score5 = metrics.r2_score(y_test,y_pred5)
score6 = metrics.r2_score(y_test,y_pred6)

print(score1,score2,score3,score4,score5,score6)
# Out:
# 0.9994234310992762 0.9547066777872097 0.9744166878721875 0.9533947627916037 0.9497563859782069 0.9890725273662383

# %%
final_data = pd.DataFrame({'Models':['LR','SVR','GBR','RFR','XGB','ANN'],
             'R2_Score':[score1,score2,score3,score4,score5,score6]})

# %%
import seaborn as sns

# %%
sns.barplot(x=final_data['Models'],y=final_data['R2_Score'])
# Out:
# <Axes: xlabel='Models', ylabel='R2_Score'>

# %% [markdown]
# # Save the ann model

# %%
import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense

ann = Sequential()
ann.add(Dense(25,input_dim=5,activation='relu'))
ann.add(Dense(25,activation='relu'))
ann.add(Dense(1,activation='linear'))
ann.summary()

ann.compile(optimizer='adam',loss='mean_squared_error')
ann.fit(X_scaled,y_scaled,epochs=100,batch_size=50,verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 25)                150
#
#  dense_4 (Dense)             (None, 25)                650
#
#  dense_5 (Dense)             (None, 1)                 26
#
# ...
# Total params: 826
# Trainable params: 826
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 1s 3ms/step - loss: 0.1301
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0315
# Epoch 3/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0182
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0143
# Epoch 6/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0121
# ...

# %%
import joblib

joblib.dump(ann,'model_ann_CarPurchase')
# Out:
# ['model_ann_CarPurchase']

# %%
model = joblib.load('model_ann_CarPurchase')

# %% [markdown]
# # Prediction on new data

# %%
import numpy as np
X_test1 = sc.transform(np.array([[0,42,62812.09301,11609.38091,238961.2505]]))
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
X_test1
# Out:
# array([[0.        , 0.44      , 0.53515116, 0.57836085, 0.22342985]])

# %%
predann = model.predict(X_test1)
# Out:
# 1/1 [==============================] - 0s 48ms/step

# %%
predann
# Out:
# array([[0.3724825]], dtype=float32)

# %%
sc1.inverse_transform(predann)
# Out:
# array([[35446.258]], dtype=float32)

# %%
data.head(1)
# Out:
#    Customer Name                                    Customer e-mail Country  \
# 0  Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu     USA
#
#    Gender  Age  Annual Salary  Credit Card Debt    Net Worth  \
# 0       0   42    62812.09301       11609.38091  238961.2505
#
#    Car Purchase Amount
# 0          35321.45877

# %%
def show_entry_field():
    p1=int(e4.get())
    p2=float(e5.get())
    p3=float(e6.get())
    p4=float(e7.get())
    p5=float(e8.get())
    
    model = joblib.load("model_ann_CarPurchase")
    
    inputdata = sc.transform(np.array([[p1,p2,p3,p4,p5]]))
    result = model.predict([[inputdata]])
    result1 = sc1.inverse_transform(result)
    Label(master, text="Your Car Purchase amount is").grid(row=10)
    Label(master, text=result1[0][0], bg = 'grey',fg = 'white').grid(row=10,columnspan = 2)
    print("Car Purchase amount is", result1[0][0])

from tkinter import *
import joblib
from sklearn.preprocessing import MinMaxScaler
import numpy as np

master = Tk()
master.title("CAR PURCHASE")
label = Label(master, text = "Car Purchase Amount Prediction using ML", bg = 'black',fg = 'white').grid(row = 0, columnspan = 2)
Label(master, text = "Enter your name").grid(row=1)
Label(master, text = "Enter the Email-ID").grid(row=2)
Label(master, text = "Enter your Country").grid(row=3)
Label(master, text = "Enter the Gender (Male/Female,(1/0))").grid(row=4)
Label(master, text = "Enter your Age").grid(row=5)
Label(master, text = "Enter your Annual Salary").grid(row=6)
Label(master, text = "Enter the Credit card debit").grid(row=7)
Label(master, text = "Enter the Net Worth").grid(row=8)

e1=Entry(master)
e2=Entry(master)
e3=Entry(master)
e4=Entry(master)
e5=Entry(master)
e6=Entry(master)
e7=Entry(master)
e8=Entry(master)

e1.grid(row=1,column=1)
e2.grid(row=2,column=1)
e3.grid(row=3,column=1)
e4.grid(row=4,column=1)
e5.grid(row=5,column=1)
e6.grid(row=6,column=1)
e7.grid(row=7,column=1)
e8.grid(row=8,column=1)

Button(master, text="Predict",command=show_entry_field).grid()

mainloop()

# %%
from ann_visualizer.visualize import ann_viz;
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from ann_visualizer.visualize import ann_viz
#
# ModuleNotFoundError: No module named 'ann_visualizer'

# %% [markdown]
# #
